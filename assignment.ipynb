# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as ps

# %%
url="https://www.91mobiles.com/samsung-mobile-price-list-in-india"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
mobile=BeautifulSoup(response.text)

# %%
mobile
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <script type="text/javascript">
#             var menu_cat_id = 553;
#             var floating_menu = true;
#         </script>
# <meta content="text/html;" http-equiv="content-type"/>
# <title>Samsung Mobile Phones Price List in India (Apr 2023) | 91mobiles.com</title>
# <meta content="Price list of all Samsung mobile phones in India with specifications and features from different online stores at 91mobiles. Read user reviews, compare mobile prices and ask questions." name="description"/>
# <meta content="Samsung mobile price, Samsung mobile price list, Samsung mobile price list in India, Samsung mobile price in India, price of Samsung mobile, Samsung mobile list. " name="keywords"/>
# <meta content="132814090096744" property="fb:pages"/>
# <!-- <meta name="google-site-verification" content="" /> -->
# <meta content="VJxqEyygt3C1CTUDiorRtHqGOgsubqBfI6KDSNKTruY" name="google-site-verification"/>
# ...

# %%
product=mobile.select(".name")

# %%
product
# Out:
# [<a class="hover_blue_link name gaclick" data-type="name" href="/samsung-galaxy-a54-5g-price-in-india" target="_blank" title="Samsung Galaxy A54 5G">
#                                   Samsung Galaxy A54 5G                             </a>,
#  <a class="hover_blue_link name gaclick" data-type="name" href="/samsung-galaxy-s23-ultra-5g-price-in-india" target="_blank" title="Samsung Galaxy S23 Ultra 5G">
#                                   Samsung Galaxy S23 Ultra 5G                             </a>,
#  <a class="hover_blue_link name gaclick" data-type="name" href="/samsung-galaxy-a14-5g-price-in-india" target="_blank" title="Samsung Galaxy A14 5G">
#                                   Samsung Galaxy A14 5G                             </a>,
#  <a class="hover_blue_link name gaclick" data-type="name" href="/samsung-galaxy-s21-fe-price-in-india" target="_blank" title="Samsung Galaxy S21 FE">
#                                   Samsung Galaxy S21 FE                             </a>,
# ...

# %%
import pandas as pds

# %%
table=pds.DataFrame(product,columns=["mobile name"])

# %%
table
# Out:
#                                           mobile name
# 0   [\n                                 Samsung Ga...
# 1   [[See Full Specifications\n              , [],...
# 2   [\n                                 Samsung Ga...
# 3   [[See Full Specifications\n              , [],...
# 4   [\n                                 Samsung Ga...
# 5   [[See Full Specifications\n              , [],...
# 6   [\n                                 Samsung Ga...
# 7   [[See Full Specifications\n              , [],...
# 8   [\n                                 Samsung Ga...
# 9   [[See Full Specifications\n              , [],...
# 10  [\n                                 Samsung Ga...
# 11  [[See Full Specifications\n              , [],...
# 12  [\n                                 Samsung Ga...
# 13  [[See Full Specifications\n              , [],...
# 14  [\n                                 Samsung Ga...
# 15  [[See Full Specifications\n              , [],...
# ...

# %%
price=mobile.select(".price_padding")

# %%
price
# Out:
# [<span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>38,999</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>124,999</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>16,499</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>35,800</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>14,990</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>28,251</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>74,998</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>89,659</span>,
#  <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>16,221</span>,
# ...

# %%
table=pds.DataFrame({'mobile name':product,'price':price})

# %%
table
# Out:
#                                          mobile name             price
# 0  [\n                                 Samsung Ga...   [[Rs.], 38,999]
# 1  [\n                                 Samsung Ga...  [[Rs.], 124,999]
# 2  [\n                                 Samsung Ga...   [[Rs.], 16,499]
# 3  [\n                                 Samsung Ga...   [[Rs.], 35,800]
# 4  [\n                                 Samsung Ga...   [[Rs.], 14,990]
# 5  [\n                                 Samsung Ga...   [[Rs.], 28,251]
# 6  [\n                                 Samsung Ga...   [[Rs.], 74,998]
# 7  [\n                                 Samsung Ga...   [[Rs.], 89,659]
# 8  [\n                                 Samsung Ga...   [[Rs.], 16,221]
# 9  [\n                                 Samsung Ga...   [[Rs.], 24,490]

# %%
ss=ps.DataFrame({""})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16272/3197566010.py in <module>
# ----> 1 ecommerce=pds.DataFrame(product_price)
#
# NameError: name 'product_price' is not defined
